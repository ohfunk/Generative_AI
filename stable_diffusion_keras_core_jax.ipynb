# %% [markdown]
# <a href="https://colab.research.google.com/github/ohfunk/Generative_AI/blob/main/stable_diffusion_keras_core_jax.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -q keras-cv --upgrade
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 803.1/803.1 kB 8.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 924.6/924.6 kB 47.9 MB/s eta 0:00:00

# %%
import os

os.environ["KERAS_BACKEND"] = "jax"

# %%
import keras_cv
import matplotlib.pyplot as plt
# Out:
# Using JAX backend.

# %%
model = keras_cv.models.StableDiffusion(img_width=512, img_height=512)
prompt = "photograph of a mammoth conducting an archaeological dig"
# Out:
# By using this model checkpoint, you acknowledge that its usage is subject to the terms of the CreativeML Open RAIL-M license at https://raw.githubusercontent.com/CompVis/stable-diffusion/main/LICENSE

# %%
# First run
# %time images = model.text_to_image(prompt, batch_size=3)
# Out:
# ---------------------------------------------------------------------------
# XlaRuntimeError                           Traceback (most recent call last)
# <timed exec> in <module>
#
# /usr/local/lib/python3.10/dist-packages/keras_cv/src/models/stable_diffusion/stable_diffusion.py in text_to_image(self, prompt, negative_prompt, batch_size, num_steps, unconditional_guidance_scale, seed)
#      81         encoded_text = self.encode_text(prompt)
#      82
# ---> 83         return self.generate_image(
#      84             encoded_text,
#      85             negative_prompt=negative_prompt,
#
# /usr/local/lib/python3.10/dist-packages/keras_cv/src/models/stable_diffusion/stable_diffusion.py in generate_image(self, encoded_text, negative_prompt, batch_size, num_steps, unconditional_guidance_scale, diffusion_noise, seed)
#     217             latent_prev = latent  # Set aside the previous latent vector
#     218             t_emb = self._get_timestep_embedding(timestep, batch_size)
# ...

# %%
# Second run
# %time images = model.text_to_image(prompt, batch_size=3)
# Out:
# ---------------------------------------------------------------------------
# XlaRuntimeError                           Traceback (most recent call last)
# <timed exec> in <module>
#
# /usr/local/lib/python3.10/dist-packages/keras_cv/src/models/stable_diffusion/stable_diffusion.py in text_to_image(self, prompt, negative_prompt, batch_size, num_steps, unconditional_guidance_scale, seed)
#      79         seed=None,
#      80     ):
# ---> 81         encoded_text = self.encode_text(prompt)
#      82
#      83         return self.generate_image(
#
# /usr/local/lib/python3.10/dist-packages/keras_cv/src/models/stable_diffusion/stable_diffusion.py in encode_text(self, prompt)
#     121         phrase = ops.convert_to_tensor([phrase], dtype="int32")
#     122
# --> 123         context = self.text_encoder.predict_on_batch(
#     124             {"tokens": phrase, "positions": self._get_pos_ids()}
#     125         )
#
# ...

# %%
def plot_images(images):
    plt.figure(figsize=(20, 20))
    for i in range(len(images)):
        ax = plt.subplot(1, len(images), i + 1)
        plt.imshow(images[i])
        plt.axis("off")


plot_images(images)
